# %% [markdown]
# # Day 4 - FastAPI Advanced Development
#
# ## Topics Covered
# - FastAPI Architecture
# - APIRouter
# - Pydantic v2 Validation
# - Async/Await
# - Dependency Injection
# - Background Tasks
# - CRUD API Development
# - Error Handling
# - Postman Testing
# - Production Best Practices
#
# ## Lab 4 Deliverable
# Build an Async Student CRUD API tested using Swagger UI and Postman.

# %% [markdown]
# ## FastAPI Introduction
#
# Why FastAPI, benefits, performance, automatic docs, type hints, validation.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Architecture
#
# Client -> Router -> Validation -> Service -> Database -> Response
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## APIRouter
#
# Modular API design and project structure.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Pydantic v2
#
# Validation, Field constraints, model_dump, validators.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Async Await
#
# Coroutines, event loop, non-blocking I/O.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Dependency Injection
#
# Depends(), reusable components.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Background Tasks
#
# Email, ETL trigger, logging use cases.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Error Handling
#
# HTTPException, status codes.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## CRUD API
#
# GET, POST, PUT, DELETE.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Testing
#
# Swagger UI and Postman.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Interview Questions
#
# Beginner to advanced.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %% [markdown]
# ## Best Practices
#
# Production architecture and coding standards.
#
# ### Detailed Explanation
# Explain concept, real-world usage, advantages, limitations, common mistakes, and interview notes.

# %%
# Install Dependencies
# pip install fastapi uvicorn pydantic email-validator requests

# %% [markdown]
# ## Project Structure
#
# ```text
# student_api/
# ├── main.py
# ├── routers/
# │   └── students.py
# ├── models/
# │   └── student.py
# ├── services/
# │   └── student_service.py
# └── requirements.txt
# ```

# %%
from pydantic import BaseModel, Field, EmailStr

class Student(BaseModel):
    # Unique identifier
    id: int

    # Student name validation
    name: str = Field(min_length=2, max_length=50)

    # Age must be positive
    age: int = Field(gt=0, lt=100)

    # Email validation requires email-validator package
    email: EmailStr

    # Course enrolled
    course: str

# %% [markdown]
# ### Code Explanation
#
# - BaseModel provides validation.
# - Field() adds constraints.
# - EmailStr validates email format.
# - Invalid data automatically returns HTTP 422.

# %%
import asyncio

async def fetch_student():
    # Simulate database call
    await asyncio.sleep(1)
    return "Student Data"

# %% [markdown]
# ### Async Explanation
#
# Why async?
# - Better performance for I/O operations.
# - Doesn't block server threads.
# - Useful for APIs, databases, file operations, cloud services.

# %%
from fastapi import Depends

def get_db():
    # Simulated database connection
    return "DB Connection"

def get_current_user():
    return {"user":"admin"}

# %% [markdown]
# ### Dependency Injection Explanation
#
# Benefits:
# 1. Reusability
# 2. Loose coupling
# 3. Easier testing
# 4. Cleaner code

# %%
from fastapi import BackgroundTasks

def send_welcome_email(email: str):
    print(f"Welcome email sent to {email}")

# %% [markdown]
# ## Complete CRUD API

# %%
from fastapi import FastAPI, HTTPException, BackgroundTasks
from pydantic import BaseModel, EmailStr, Field

app = FastAPI()

students = []

class Student(BaseModel):
    id: int
    name: str = Field(min_length=2)
    age: int = Field(gt=0)
    email: EmailStr
    course: str

def send_welcome_email(email: str):
    print(f"Email sent to {email}")

@app.get('/students')
async def get_students():
    # Return all students
    return students

@app.get('/students/{student_id}')
async def get_student(student_id: int):
    # Search student by ID
    for student in students:
        if student['id'] == student_id:
            return student

    raise HTTPException(
        status_code=404,
        detail='Student not found'
    )

@app.post('/students')
async def create_student(
    student: Student,
    background_tasks: BackgroundTasks
):
    students.append(student.model_dump())

    background_tasks.add_task(
        send_welcome_email,
        student.email
    )

    return {
        'message':'Student Created',
        'student':student
    }

@app.put('/students/{student_id}')
async def update_student(
    student_id: int,
    updated_student: Student
):
    for index, student in enumerate(students):
        if student['id'] == student_id:
            students[index] = updated_student.model_dump()

            return {
                'message':'Student Updated'
            }

    raise HTTPException(
        status_code=404,
        detail='Student not found'
    )

@app.delete('/students/{student_id}')
async def delete_student(student_id: int):
    for index, student in enumerate(students):
        if student['id'] == student_id:
            students.pop(index)

            return {
                'message':'Student Deleted'
            }

    raise HTTPException(
        status_code=404,
        detail='Student not found'
    )

# %% [markdown]
# ## Interview Question 1
#
# ### Question
# Sample FastAPI interview question 1.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 2
#
# ### Question
# Sample FastAPI interview question 2.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 3
#
# ### Question
# Sample FastAPI interview question 3.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 4
#
# ### Question
# Sample FastAPI interview question 4.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 5
#
# ### Question
# Sample FastAPI interview question 5.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 6
#
# ### Question
# Sample FastAPI interview question 6.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 7
#
# ### Question
# Sample FastAPI interview question 7.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 8
#
# ### Question
# Sample FastAPI interview question 8.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 9
#
# ### Question
# Sample FastAPI interview question 9.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 10
#
# ### Question
# Sample FastAPI interview question 10.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 11
#
# ### Question
# Sample FastAPI interview question 11.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 12
#
# ### Question
# Sample FastAPI interview question 12.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 13
#
# ### Question
# Sample FastAPI interview question 13.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 14
#
# ### Question
# Sample FastAPI interview question 14.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 15
#
# ### Question
# Sample FastAPI interview question 15.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 16
#
# ### Question
# Sample FastAPI interview question 16.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 17
#
# ### Question
# Sample FastAPI interview question 17.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 18
#
# ### Question
# Sample FastAPI interview question 18.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 19
#
# ### Question
# Sample FastAPI interview question 19.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Interview Question 20
#
# ### Question
# Sample FastAPI interview question 20.
#
# ### Answer
# Detailed answer explaining the concept, use cases, best practices, and production considerations.

# %% [markdown]
# ## Exercise 1
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 2
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 3
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 4
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 5
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 6
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 7
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 8
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 9
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# ## Exercise 10
#
# Task:
# Implement a FastAPI feature related to routers, validation, async operations, dependency injection, or CRUD.
#
# ### Solution Approach
# Step-by-step guidance.

# %% [markdown]
# # Running the Project
#
# ## Step 1
# Create main.py
#
# ## Step 2
# Install dependencies
#
# ```bash
# pip install fastapi uvicorn pydantic email-validator
# ```
#
# ## Step 3
# Run application
#
# ```bash
# uvicorn main:app --reload
# ```
#
# ## Step 4
# Open Swagger
#
# http://127.0.0.1:8000/docs
#
# ## Step 5
# Test POST API
#
# ```json
# {
#   "id": 1,
#   "name": "Nagendra",
#   "age": 25,
#   "email": "nagendra@test.com",
#   "course": "Data Engineering"
# }
# ```
#
# ## Step 6
# Test GET, PUT and DELETE APIs.

# %% [markdown]
# # End-to-End Explanation of the Complete File
#
# 1. FastAPI creates API endpoints.
# 2. APIRouter helps modularize code.
# 3. Pydantic validates incoming requests.
# 4. Async endpoints improve scalability.
# 5. Dependency Injection provides reusable dependencies.
# 6. BackgroundTasks execute work after response.
# 7. CRUD endpoints perform create, read, update and delete operations.
# 8. HTTPException handles failures.
# 9. Swagger UI provides interactive testing.
# 10. Postman is used for professional API testing.
#
# ### Common Mistakes
#
# - Forgetting await
# - Missing email-validator package
# - Blocking code inside async functions
# - Not using routers
# - No validation rules
# - No error handling
#
# ### Production Improvements
#
# - PostgreSQL
# - SQLAlchemy
# - Alembic
# - Docker
# - Kubernetes
# - JWT Authentication
# - Logging
# - CI/CD
# - Unit Testing
# - Redis Caching
